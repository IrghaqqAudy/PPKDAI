# %%
# !pip install pandas requests

# %%
import json
import pandas as pd
import requests

# %%
data = pd.read_json("response.json")

# %%
url = "https://data.bmkg.go.id/DataMKG/TEWS/gempaterkini.json"
response = requests.get(url)

print(f"Status Code : {response.status_code}")
# Out:
# Status Code : 200

# %%
with open("response.json", 'r') as file:
    data = json.load(file)

# %%
data = response.json()
print(data)
# Out:
# {'Infogempa': {'gempa': [{'Tanggal': '22 Sep 2026', 'Jam': '06:48:13 WIB', 'DateTime': '2026-09-21T23:48:13+00:00', 'Coordinates': '4.74,125.30', 'Lintang': '4.74 LU', 'Bujur': '125.30 BT', 'Magnitude': '5.2', 'Kedalaman': '10 km', 'Wilayah': '127 km BaratLaut TAHUNA-KEP.SANGIHE-SULUT', 'Potensi': 'Tidak berpotensi tsunami'}, {'Tanggal': '21 Sep 2026', 'Jam': '14:31:07 WIB', 'DateTime': '2026-09-21T07:31:07+00:00', 'Coordinates': '-0.70,122.45', 'Lintang': '0.70 LS', 'Bujur': '122.45 BT', 'Magnitude': '5.3', 'Kedalaman': '10 km', 'Wilayah': '26 km BaratDaya PULAUPUAH-SULTENG', 'Potensi': 'Tidak berpotensi tsunami'}, {'Tanggal': '21 Sep 2026', 'Jam': '08:41:37 WIB', 'DateTime': '2026-09-21T01:41:37+00:00', 'Coordinates': '-8.33,120.59', 'Lintang': '8.33 LS', 'Bujur': '120.59 BT', 'Magnitude': '5.3', 'Kedalaman': '10 km', 'Wilayah': '34 km TimurLaut RUTENG-MANGGARAI-NTT', 'Potensi': 'Tidak berpotensi tsunami'}, {'Tanggal': '19 Sep 2026', 'Jam': '11:18:36 WIB', 'DateTime': '2026-09-19T0
# ...

# %%
df = pd.DataFrame(data['Infogempa']['gempa'])
df.head()
# Out:
#        Tanggal           Jam                   DateTime   Coordinates  \
# 0  22 Sep 2026  06:48:13 WIB  2026-09-21T23:48:13+00:00   4.74,125.30
# 1  21 Sep 2026  14:31:07 WIB  2026-09-21T07:31:07+00:00  -0.70,122.45
# 2  21 Sep 2026  08:41:37 WIB  2026-09-21T01:41:37+00:00  -8.33,120.59
# 3  19 Sep 2026  11:18:36 WIB  2026-09-19T04:18:36+00:00  -1.60,138.88
# 4  18 Sep 2026  21:36:17 WIB  2026-09-18T14:36:17+00:00  -8.64,105.74
#
#    Lintang      Bujur Magnitude Kedalaman  \
# 0  4.74 LU  125.30 BT       5.2     10 km
# 1  0.70 LS  122.45 BT       5.3     10 km
# 2  8.33 LS  120.59 BT       5.3     10 km
# 3  1.60 LS  138.88 BT       5.1     10 km
# 4  8.64 LS  105.74 BT       5.2     10 km
#
#                                      Wilayah                   Potensi
# 0  127 km BaratLaut TAHUNA-KEP.SANGIHE-SULUT  Tidak berpotensi tsunami
# 1          26 km BaratDaya PULAUPUAH-SULTENG  Tidak berpotensi tsunami
# 2       34 km TimurLaut RUTENG-MANGGARAI-NTT  Tidak berpotensi tsunami
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Tanggal      15 non-null     str
#  1   Jam          15 non-null     str
#  2   DateTime     15 non-null     str
#  3   Coordinates  15 non-null     str
#  4   Lintang      15 non-null     str
#  5   Bujur        15 non-null     str
#  6   Magnitude    15 non-null     str
#  7   Kedalaman    15 non-null     str
#  8   Wilayah      15 non-null     str
#  9   Potensi      15 non-null     str
# dtypes: str(10)
# memory usage: 1.3 KB

# %%
url = "https://api.openweathermap.org/data/2.5/weather?q=Jakarta&appid=4527da338b1f2b511cce8978c0b36d71"
response = requests.get(url)

print(f"Status Code : {response.status_code}")
# Out:
# Status Code : 200

# %%
with open("response.json", 'r') as file:
    data = json.load(file)

# %%
data = response.json()
print(data)
# Out:
# {'coord': {'lon': 106.8451, 'lat': -6.2146}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 303.11, 'feels_like': 308.83, 'temp_min': 302.09, 'temp_max': 304.11, 'pressure': 1013, 'humidity': 73, 'sea_level': 1013, 'grnd_level': 1011}, 'visibility': 10000, 'wind': {'speed': 3.6, 'deg': 60}, 'clouds': {'all': 78}, 'dt': 1790042690, 'sys': {'type': 2, 'id': 2108225, 'country': 'ID', 'sunrise': 1790030545, 'sunset': 1790074122}, 'timezone': 25200, 'id': 1642911, 'name': 'Jakarta', 'cod': 200}

# %%
# !pip install python-dotenv

# %%
print("Tess")
# Out:
# Tess

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\TIK 11\miniconda3\envs\PPKDAI\python.exe

# %%
import os 
import requests
import pandas as pd
from dotenv import load_dotenv

# %%
load_dotenv()
API_KEY = os.getenv("openweather_API_KEY")

# %%
url = "https://api.openweathermap.org/data/2.5/weather?q=Jakarta&appid=openweather_API_KEY"
params = {
    "q": "Jakarta",
    "appid": API_KEY,
    "units": "metric"
}

response = requests.get(url, params=params)
print(f"Status Code : {response.status_code}")
# Out:
# Status Code : 401

# %%
url = "https://api.openweathermap.org/data/2.5/weather?"
params = {
    "q": "Jakarta",
    "appid": API_KEY,
    "units": "metric"
}

response = requests.get(url, params=params)
print(f"Status Code : {response.status_code}")
# Out:
# Status Code : 200
